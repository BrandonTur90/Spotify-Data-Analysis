# %% [markdown]
# # Popularity of a song in Spotify

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Imports our dependencies
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# Load the data
song_df = pd.read_csv("./Resources/songfeatures.csv")
song_df
# Out:
#                   Artist  Streams        Date        genre  \
# 0                Shakira   244295  2017-01-01        Dance
# 1      Twenty One Pilots   227187  2017-01-01         Rock
# 2          Bryson Tiller   213378  2017-01-01      Hip-Hop
# 3           Lil Uzi Vert   208263  2017-01-01          Rap
# 4           Van Morrison   175044  2017-01-01         Folk
# ...                  ...      ...         ...          ...
# 45714           Lil Pump  1358590  2017-12-02      Hip-Hop
# 45715         Famous Dex   687790  2017-12-02      Hip-Hop
# 45716              6LACK   181424  2017-12-03  Alternative
# 45717           Lil Pump  1175011  2017-12-04      Hip-Hop
# 45718         Famous Dex   715066  2017-12-04      Hip-Hop
#
#                           track_name                track_id  popularity  \
# 0            Chantaje (feat. Maluma)  6mICuAdrwEjh6Y6lroV2Kg          78
# 1                       Stressed Out  3CRDbSIZ4r5MsZ0YwxuEkn          84
# 2                              Don't  3pXF1nA74528Edde4of9CC          79
# 3                  Erase Your Social  4uhvMW7ly7tJil31YYscAN          75
# 4                    Brown Eyed Girl  3yrSvpt2l1xhsV9Em88Pul          80
# ...                              ...                     ...         ...
# 45714                     Gucci Gang  43ZyHQITOjhciSUUNPVRHc          78
# 45715  PICK IT UP (feat. A$AP Rocky)  3ncgNpxLoBQ65ABk4djDyd          79
# 45716                     Ex Calling  1MQ8ydvrTnn2QJgXFATJvD          67
# 45717                     Gucci Gang  43ZyHQITOjhciSUUNPVRHc          78
# 45718  PICK IT UP (feat. A$AP Rocky)  3ncgNpxLoBQ65ABk4djDyd          79
#
#        acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 0           0.18700         0.852       195840   0.773          0.000030  G#
# 1           0.04620         0.734       202333   0.637          0.000023   E
# 2           0.22200         0.765       198293   0.356          0.000000   B
# 3           0.69400         0.705       199993   0.609          0.000000  D#
# 4           0.18200         0.491       183307   0.583          0.000000   G
# ...             ...           ...          ...     ...               ...  ..
# 45714       0.23900         0.936       124056   0.523          0.000000   F
# 45715       0.01490         0.921       191252   0.467          0.000238  C#
# 45716       0.00561         0.773       211960   0.564          0.000020  C#
# 45717       0.23900         0.936       124056   0.523          0.000000   F
# 45718       0.01490         0.921       191252   0.467          0.000238  C#
#
#        liveness  loudness   mode  speechiness    tempo time_signature  valence
# 0        0.1590    -2.921  Minor       0.0776  102.034            4/4   0.9070
# 1        0.0602    -5.677  Minor       0.1410  169.977            4/4   0.6480
# 2        0.0963    -5.556  Minor       0.1960   97.001            4/4   0.1900
# 3        0.2340    -5.728  Major       0.0729  140.058            4/4   0.7180
# 4        0.4070   -10.964  Major       0.0376  150.572            4/4   0.9070
# ...         ...       ...    ...          ...      ...            ...      ...
# 45714    0.1170    -6.710  Major       0.0597  119.889            4/4   0.6990
# 45715    0.3340    -8.443  Major       0.1190  135.995            4/4   0.2870
# 45716    0.2130    -7.241  Major       0.2490  155.976            4/4   0.0588
# 45717    0.1170    -6.710  Major       0.0597  119.889            4/4   0.6990
# 45718    0.3340    -8.443  Major       0.1190  135.995            4/4   0.2870
#
# [45719 rows x 20 columns]

# %%
song_df['Above Avg Streams']= song_df['Streams'].apply(lambda x: '1' if x >= 500000 else '0')
                
song_df
# Out:
#                   Artist  Streams        Date        genre  \
# 0                Shakira   244295  2017-01-01        Dance
# 1      Twenty One Pilots   227187  2017-01-01         Rock
# 2          Bryson Tiller   213378  2017-01-01      Hip-Hop
# 3           Lil Uzi Vert   208263  2017-01-01          Rap
# 4           Van Morrison   175044  2017-01-01         Folk
# ...                  ...      ...         ...          ...
# 45714           Lil Pump  1358590  2017-12-02      Hip-Hop
# 45715         Famous Dex   687790  2017-12-02      Hip-Hop
# 45716              6LACK   181424  2017-12-03  Alternative
# 45717           Lil Pump  1175011  2017-12-04      Hip-Hop
# 45718         Famous Dex   715066  2017-12-04      Hip-Hop
#
#                           track_name                track_id  popularity  \
# 0            Chantaje (feat. Maluma)  6mICuAdrwEjh6Y6lroV2Kg          78
# 1                       Stressed Out  3CRDbSIZ4r5MsZ0YwxuEkn          84
# 2                              Don't  3pXF1nA74528Edde4of9CC          79
# 3                  Erase Your Social  4uhvMW7ly7tJil31YYscAN          75
# 4                    Brown Eyed Girl  3yrSvpt2l1xhsV9Em88Pul          80
# ...                              ...                     ...         ...
# 45714                     Gucci Gang  43ZyHQITOjhciSUUNPVRHc          78
# 45715  PICK IT UP (feat. A$AP Rocky)  3ncgNpxLoBQ65ABk4djDyd          79
# 45716                     Ex Calling  1MQ8ydvrTnn2QJgXFATJvD          67
# 45717                     Gucci Gang  43ZyHQITOjhciSUUNPVRHc          78
# 45718  PICK IT UP (feat. A$AP Rocky)  3ncgNpxLoBQ65ABk4djDyd          79
#
#        acousticness  danceability  duration_ms  ...  instrumentalness  key  \
# 0           0.18700         0.852       195840  ...          0.000030   G#
# 1           0.04620         0.734       202333  ...          0.000023    E
# 2           0.22200         0.765       198293  ...          0.000000    B
# 3           0.69400         0.705       199993  ...          0.000000   D#
# 4           0.18200         0.491       183307  ...          0.000000    G
# ...             ...           ...          ...  ...               ...  ...
# 45714       0.23900         0.936       124056  ...          0.000000    F
# 45715       0.01490         0.921       191252  ...          0.000238   C#
# 45716       0.00561         0.773       211960  ...          0.000020   C#
# 45717       0.23900         0.936       124056  ...          0.000000    F
# 45718       0.01490         0.921       191252  ...          0.000238   C#
#
#       liveness  loudness   mode speechiness    tempo  time_signature valence  \
# 0       0.1590    -2.921  Minor      0.0776  102.034             4/4  0.9070
# 1       0.0602    -5.677  Minor      0.1410  169.977             4/4  0.6480
# 2       0.0963    -5.556  Minor      0.1960   97.001             4/4  0.1900
# 3       0.2340    -5.728  Major      0.0729  140.058             4/4  0.7180
# 4       0.4070   -10.964  Major      0.0376  150.572             4/4  0.9070
# ...        ...       ...    ...         ...      ...             ...     ...
# 45714   0.1170    -6.710  Major      0.0597  119.889             4/4  0.6990
# 45715   0.3340    -8.443  Major      0.1190  135.995             4/4  0.2870
# 45716   0.2130    -7.241  Major      0.2490  155.976             4/4  0.0588
# 45717   0.1170    -6.710  Major      0.0597  119.889             4/4  0.6990
# 45718   0.3340    -8.443  Major      0.1190  135.995             4/4  0.2870
#
#        Above Avg Streams
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 45714                  1
# 45715                  1
# 45716                  0
# 45717                  1
# 45718                  1
#
# [45719 rows x 21 columns]

# %%
#  Remove all the non numeric value columns
ml_df= song_df[[ 'Above Avg Streams', 'acousticness', 'danceability', 'duration_ms', 'energy', 'key', 'mode', 'instrumentalness','liveness', 'loudness', 'speechiness', 'tempo', 'valence']]

ml_df.head()
# Out:
#   Above Avg Streams  acousticness  danceability  duration_ms  energy key  \
# 0                 0        0.1870         0.852       195840   0.773  G#
# 1                 0        0.0462         0.734       202333   0.637   E
# 2                 0        0.2220         0.765       198293   0.356   B
# 3                 0        0.6940         0.705       199993   0.609  D#
# 4                 0        0.1820         0.491       183307   0.583   G
#
#     mode  instrumentalness  liveness  loudness  speechiness    tempo  valence
# 0  Minor          0.000030    0.1590    -2.921       0.0776  102.034    0.907
# 1  Minor          0.000023    0.0602    -5.677       0.1410  169.977    0.648
# 2  Minor          0.000000    0.0963    -5.556       0.1960   97.001    0.190
# 3  Major          0.000000    0.2340    -5.728       0.0729  140.058    0.718
# 4  Major          0.000000    0.4070   -10.964       0.0376  150.572    0.907

# %%
#song_df_encoded = pd.get_dummies(song_df, columns=["mode"])
#song_df_encoded.head()

# %%
#Transforming the column 'mode' from text to numerical value
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
song2_df = ml_df.copy()
song2_df['mode'] = le.fit_transform(song2_df['mode'])
song2_df
# Out:
#       Above Avg Streams  acousticness  danceability  duration_ms  energy key  \
# 0                     0       0.18700         0.852       195840   0.773  G#
# 1                     0       0.04620         0.734       202333   0.637   E
# 2                     0       0.22200         0.765       198293   0.356   B
# 3                     0       0.69400         0.705       199993   0.609  D#
# 4                     0       0.18200         0.491       183307   0.583   G
# ...                 ...           ...           ...          ...     ...  ..
# 45714                 1       0.23900         0.936       124056   0.523   F
# 45715                 1       0.01490         0.921       191252   0.467  C#
# 45716                 0       0.00561         0.773       211960   0.564  C#
# 45717                 1       0.23900         0.936       124056   0.523   F
# 45718                 1       0.01490         0.921       191252   0.467  C#
#
#        mode  instrumentalness  liveness  loudness  speechiness    tempo  \
# 0         1          0.000030    0.1590    -2.921       0.0776  102.034
# 1         1          0.000023    0.0602    -5.677       0.1410  169.977
# 2         1          0.000000    0.0963    -5.556       0.1960   97.001
# 3         0          0.000000    0.2340    -5.728       0.0729  140.058
# 4         0          0.000000    0.4070   -10.964       0.0376  150.572
# ...     ...               ...       ...       ...          ...      ...
# 45714     0          0.000000    0.1170    -6.710       0.0597  119.889
# 45715     0          0.000238    0.3340    -8.443       0.1190  135.995
# 45716     0          0.000020    0.2130    -7.241       0.2490  155.976
# 45717     0          0.000000    0.1170    -6.710       0.0597  119.889
# 45718     0          0.000238    0.3340    -8.443       0.1190  135.995
#
#        valence
# 0       0.9070
# 1       0.6480
# 2       0.1900
# 3       0.7180
# 4       0.9070
# ...        ...
# 45714   0.6990
# 45715   0.2870
# 45716   0.0588
# 45717   0.6990
# 45718   0.2870
#
# [45719 rows x 13 columns]

# %%
#Transforming the column 'key' from text to numerical value
le = LabelEncoder()
df = song2_df.copy()
df['key'] = le.fit_transform(df['key'])
df
# Out:
#       Above Avg Streams  acousticness  danceability  duration_ms  energy  key  \
# 0                     0       0.18700         0.852       195840   0.773   11
# 1                     0       0.04620         0.734       202333   0.637    7
# 2                     0       0.22200         0.765       198293   0.356    2
# 3                     0       0.69400         0.705       199993   0.609    6
# 4                     0       0.18200         0.491       183307   0.583   10
# ...                 ...           ...           ...          ...     ...  ...
# 45714                 1       0.23900         0.936       124056   0.523    8
# 45715                 1       0.01490         0.921       191252   0.467    4
# 45716                 0       0.00561         0.773       211960   0.564    4
# 45717                 1       0.23900         0.936       124056   0.523    8
# 45718                 1       0.01490         0.921       191252   0.467    4
#
#        mode  instrumentalness  liveness  loudness  speechiness    tempo  \
# 0         1          0.000030    0.1590    -2.921       0.0776  102.034
# 1         1          0.000023    0.0602    -5.677       0.1410  169.977
# 2         1          0.000000    0.0963    -5.556       0.1960   97.001
# 3         0          0.000000    0.2340    -5.728       0.0729  140.058
# 4         0          0.000000    0.4070   -10.964       0.0376  150.572
# ...     ...               ...       ...       ...          ...      ...
# 45714     0          0.000000    0.1170    -6.710       0.0597  119.889
# 45715     0          0.000238    0.3340    -8.443       0.1190  135.995
# 45716     0          0.000020    0.2130    -7.241       0.2490  155.976
# 45717     0          0.000000    0.1170    -6.710       0.0597  119.889
# 45718     0          0.000238    0.3340    -8.443       0.1190  135.995
#
#        valence
# 0       0.9070
# 1       0.6480
# 2       0.1900
# 3       0.7180
# 4       0.9070
# ...        ...
# 45714   0.6990
# 45715   0.2870
# 45716   0.0588
# 45717   0.6990
# 45718   0.2870
#
# [45719 rows x 13 columns]

# %% [markdown]
# # Split the Data into Training and Testing

# %%
# Create our features
X =df.drop(columns="Above Avg Streams", axis=1)


# Create our target
y = df["Above Avg Streams"]

# %%
X.describe()
# Out:
#        acousticness  danceability    duration_ms        energy           key  \
# count  45719.000000  45719.000000   45719.000000  45719.000000  45719.000000
# mean       0.194346      0.715181  219834.549268      0.589811      5.402655
# std        0.197109      0.131536   43935.095517      0.154051      3.531595
# min        0.000019      0.148000   46960.000000      0.098200      0.000000
# 25%        0.049600      0.638000  194613.000000      0.489000      2.000000
# 50%        0.119000      0.732000  218674.000000      0.586000      4.000000
# 75%        0.264000      0.804000  243837.000000      0.711000      9.000000
# max        0.994000      0.967000  728413.000000      0.995000     11.000000
#
#                mode  instrumentalness      liveness      loudness  \
# count  45719.000000      45719.000000  45719.000000  45719.000000
# mean       0.443820          0.004290      0.156315     -6.732634
# std        0.496839          0.031217      0.098083      2.321580
# min        0.000000          0.000000      0.021500    -22.507000
# 25%        0.000000          0.000000      0.097600     -7.817000
# 50%        0.000000          0.000000      0.123000     -6.388000
# 75%        1.000000          0.000010      0.180000     -5.151000
# max        1.000000          0.939000      0.919000     -0.804000
#
#         speechiness         tempo       valence
# count  45719.000000  45719.000000  45719.000000
# mean       0.158591    121.161888      0.439725
# std        0.130121     28.291506      0.209069
# min        0.023200     46.718000      0.037300
# 25%        0.052300     97.985000      0.281000
# 50%        0.103000    123.956000      0.422000
# 75%        0.244000    139.999000      0.605000
# max        0.623000    232.690000      0.971000

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# 0    37643
# 1     8076
# Name: Above Avg Streams, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
X_train.shape
# Out:
# (34289, 12)

# %%
#from sklearn import preprocessing
#scaler = preprocessing.StandardScaler().fit(X_train)
#X_train_scaled = scaler.transform(X_train)

# %%
import matplotlib.colors as mcolors
colors = list(mcolors.CSS4_COLORS.keys())[10:]
def draw_histograms(dataframe, features, rows, cols):
    fig=plt.figure(figsize=(20,20))
    for i, feature in enumerate(features):
        ax=fig.add_subplot(rows,cols,i+1)
        dataframe[feature].hist(bins=20,ax=ax,facecolor=colors[i])
        ax.set_title(feature+" Histogram",color=colors[35])
        ax.set_yscale('log')
    fig.tight_layout() 
    plt.savefig('Histograms.png')
    plt.show()
draw_histograms(df,df.columns,8,4)

# %%
plt.figure(figsize = (38,16))
sns.heatmap(df.corr(), annot = True)
plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# # Create a Logistic Regression model

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
   max_iter=200,
   random_state=1)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array(['0', '0', '0', ..., '0', '0', '0'], dtype=object)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import accuracy_score
test_acc = accuracy_score(y_test, y_pred)
print("The Accuracy for Test Set is {}".format(test_acc*100))
# Out:
# The Accuracy for Test Set is 82.33595800524934

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix, classification_report
matrix = confusion_matrix(y_test, y_pred)
print(matrix)
# Out:
# [[9411    0]
#  [2019    0]]

# %%
cm=confusion_matrix(y_test,y_pred)
plt.figure(figsize=(12,6))
plt.title("Confusion Matrix")
sns.heatmap(cm, annot=True,fmt='d', cmap='Blues')
plt.ylabel("Actual Values")
plt.xlabel("Predicted Values")
plt.savefig('confusion_matrix.png')

# %%
# Print the classification report
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90      9411
#            1       0.00      0.00      0.00      2019
#
#     accuracy                           0.82     11430
#    macro avg       0.41      0.50      0.45     11430
# weighted avg       0.68      0.82      0.74     11430
